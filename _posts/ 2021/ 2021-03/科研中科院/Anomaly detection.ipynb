# %%
from pandas import read_csv
from sklearn.model_selection import train_test_split
import pandas as pd
# load the dataset
df2 = pd.read_csv("/content/test1.csv")
df1 = pd.read_csv("/content/train.csv")
 
# retrieve the array
data1 = df1[[ 'actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3']]
data2 = df2[[ 'actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3']]
# split into input and output elements
data1 = data1.values
data2 = data2.values
X_train, y_train = data1[:, :-1], data1[:, -1]
# split into input and output elements
X_test, y_test = data2[:, :-1], data2[:, -1]
# summarize the shape of the train and test sets
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# fit the model
model = LinearRegression()
model.fit(X_train, y_train)
# evaluate the model
yhat = model.predict(X_test)
# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# (200000, 31) (50000, 31) (200000,) (50000,)
# MAE: 2644.324

# %%
# identify outliers in the training dataset
from sklearn.ensemble import IsolationForest
iso = IsolationForest(contamination=0.1)
yhat = iso.fit_predict(X_train)
yhat
# Out:
# array([ 1,  1,  1, ..., -1, -1, -1])

# %%
yhat2 = iso.fit_predict(X_test)
yhat2
# Out:
# array([-1, -1, -1, ...,  1,  1,  1])

# %%
y_test
# Out:
# array([377.06, 377.06, 377.12, ..., 414.09, 414.09, 414.09])

# %%
mask = yhat2 != -1
X_test, y_test = X_test[mask, :], y_test[mask]

# %%
y_test
# Out:
# array([377.06, 377.06, 377.12, ..., 414.09, 414.09, 414.09])

# %% [markdown]
# Perhaps the most important hyperparameter in the model is the “contamination” argument, which is used to help estimate the number of outliers in the dataset. This is a value between 0.0 and 0.5 and by default is set to 0.1.

# %%
# select all rows that are not outliers
mask = yhat != -1
X_train, y_train = X_train[mask, :], y_train[mask]

# %%
# load and summarize the dataset
from pandas import read_csv
from sklearn.model_selection import train_test_split
# load the dataset
df = pd.read_csv("/content/test1.csv")
# retrieve the array
data = df.values
# split into input and output elements
X, y = data[:, :-1], data[:, -1]
# summarize the shape of the dataset
print(X.shape, y.shape)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# summarize the shape of the train and test sets
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# fit the model
model = LinearRegression()
model.fit(X_train, y_train)
# evaluate the model
yhat = model.predict(X_test)
# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# (50000, 36) (50000,)
# (33500, 36) (16500, 36) (33500,) (16500,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-4f794f065172> in <module>()
#      17 # fit the model
#      18 model = LinearRegression()
# ---> 19 model.fit(X_train, y_train)
#      20 # evaluate the model
#      21 yhat = model.predict(X_test)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# evaluate model on the raw dataset
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
 
# retrieve the array
data = df[[ 'actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3']]
# split into input and output elements
data = data.values
X, y = data[:, :-1], data[:, -1]
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# fit the model
model = LinearRegression()
model.fit(X_train, y_train)
# evaluate the model
yhat = model.predict(X_test)
# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.166

# %%
import os
import pandas as pd
import numpy as np
from sklearn import preprocessing
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt

# %%
folder = r'/content'
data_dir = folder+'/2nd_test'
merged_data = pd.DataFrame()

for filename in os.listdir(data_dir):
    print(filename)
    dataset=pd.read_csv(os.path.join(data_dir, filename), sep='\t')
    dataset_mean_abs = np.array(dataset.abs().mean())
    dataset_mean_abs = pd.DataFrame(dataset_mean_abs.reshape(1,4))
    dataset_mean_abs.index = [filename]
    merged_data = merged_data.append(dataset_mean_abs)
merged_data.reset_index(inplace=True)  # reset index to get datetime as columns
merged_data.columns = ['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'] # rename columns
merged_data.sort_values(by='actc2',inplace=True)
merged_data.to_csv('2nd_test_resmaple_10minutes.csv')
# Out:
# train.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-9043bf2e45ce> in <module>()
#       6     print(filename)
#       7     dataset=pd.read_csv(os.path.join(data_dir, filename), sep='\t')
# ----> 8     dataset_mean_abs = np.array(dataset.abs().mean())
#       9     dataset_mean_abs = pd.DataFrame(dataset_mean_abs.reshape(1,4))
#      10     dataset_mean_abs.index = [filename]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in abs(self)
#    9727         3    7   40  -50
#    9728         """
# -> 9729         return np.abs(self)
#    9730
#    9731     def describe(
#
# TypeError: bad operand type for abs(): 'str'

# %%
merged_data = pd.read_csv('test1.csv',index_col= 'actc2',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
#merged_data.index = pd.to_datetime(merged_data.index, format='%Y.%m.%d.%H.%M.%S')
print(merged_data.head())
# Out:
#           dbtm  dbtv     dmea     dver  ...   gasa   spr1     spr2    spr3
# actc2                                   ...
# 2      3187.08     0  3187.14  3187.14  ...  26763  41.25  6002.96  377.01
# 2      3187.08     0  3187.14  3187.14  ...  26689  41.25  5979.17  377.01
# 2      3187.16     0  3187.17  3187.17  ...  26645  41.25  6002.94  377.01
# 2      3187.16     0  3187.18  3187.18  ...  26557  41.25  5979.28  377.05
# 2      3187.14     0  3187.18  3187.18  ...  26483  41.25  6010.99  377.05
#
# [5 rows x 31 columns]

# %%
merged_data.plot()

# %%
merged_data1 = pd.read_csv('/content/2nd_test/train.csv',index_col= 'actc2',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
merged_data2 = pd.read_csv('/content/2nd_test/test1.csv',index_col= 'actc2',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
dataset_train = merged_data1 
dataset_test = merged_data2
dataset_train.plot(figsize = (12,6))

# %%
scaler = preprocessing.MinMaxScaler()

X_train = pd.DataFrame(scaler.fit_transform(dataset_train),
                              columns=dataset_train.columns,
                              index=dataset_train.index)
# Random shuffle training data
X_train.sample(frac=1)

X_test = pd.DataFrame(scaler.transform(dataset_test),
                             columns=dataset_test.columns,
                             index=dataset_test.index)
X_test.plot()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, svd_solver= 'full')
X_train_PCA = pca.fit_transform(X_train)
X_train_PCA = pd.DataFrame(X_train_PCA)
X_train_PCA.index = X_train.index

X_test_PCA = pca.transform(X_test)
X_test_PCA = pd.DataFrame(X_test_PCA)
X_test_PCA.index = X_test.index

X_train_PCA.plot()
X_test_PCA.plot()

# %%
def is_pos_def(A):
    if np.allclose(A, A.T): # check if A is Symmetric Matrices
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

def cov_matrix(data):
    covariance_matrix = np.cov(data, rowvar=False)
    if is_pos_def(covariance_matrix):
        inv_covariance_matrix = np.linalg.inv(covariance_matrix)
        if is_pos_def(inv_covariance_matrix):
            return covariance_matrix, inv_covariance_matrix
        else:
            print("Error: Inverse of Covariance Matrix is not positive definite!")
    else:
        print("Error: Covariance Matrix is not positive definite!")

def MahalanobisDist(inv_cov_matrix, mean_distr, data, verbose=False):
    inv_covariance_matrix = inv_cov_matrix
    vars_mean = mean_distr
    diff = data - vars_mean
    md = []
    for i in range(len(diff)):
        md.append(np.sqrt(diff[i].dot(inv_covariance_matrix).dot(diff[i])))
    return md

# %%
def MD_threshold(dist, extreme=False, verbose=False):
    k = 3. if extreme else 2.
    threshold = np.mean(dist) * k
    return threshold

# %%
data_train = np.array(X_train_PCA.values)
data_test = np.array(X_test_PCA.values)
cov_matrix, inv_cov_matrix  = cov_matrix(data_train)
mean_distr = data_train.mean(axis=0)
dist_test = MahalanobisDist(inv_cov_matrix, mean_distr, data_test, verbose=False)
dist_train = MahalanobisDist(inv_cov_matrix, mean_distr, data_train, verbose=False)
threshold = MD_threshold(dist_train, extreme = True)

# %%
plt.figure()
sns.distplot(np.square(dist_train),
             bins = 10,
             kde= False)
plt.xlim([0.0,15])
plt.xlabel('Mahalanobis dist *2')

plt.figure()
sns.distplot(dist_train,
             bins = 10,
             kde= True,
            color = 'green')
plt.xlim([0.0,5])
plt.xlabel('Mahalanobis dist')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Mahalanobis dist')

# %%
anomaly_train = pd.DataFrame()
anomaly_train['Mob dist']= dist_train
anomaly_train['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly_train['Anomaly'] = anomaly_train['Mob dist'] > anomaly_train['Thresh']
anomaly_train.index = X_train_PCA.index

anomaly = pd.DataFrame()
anomaly['Mob dist']= dist_test
anomaly['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly['Anomaly'] = anomaly['Mob dist'] > anomaly['Thresh']
anomaly.index = X_test_PCA.index
print(anomaly.head())
anomaly_alldata = pd.concat([anomaly_train, anomaly])
anomaly_alldata.to_csv('Anomaly_distance.csv')
# Out:
#        Mob dist    Thresh  Anomaly
# actc2
# 2      3.511012  3.848719    False
# 2      3.514277  3.848719    False
# 2      3.516078  3.848719    False
# 2      3.529692  3.848719    False
# 2      3.523391  3.848719    False

# %%
anomaly_alldata.plot(logy=True, figsize = (10,6), ylim = [1e-1,1e3], color = ['green','red'])

# %% [markdown]
# 建立自编码模型

# %%
import tensorflow as tf
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import Input 
from keras.models import Model 
from keras.layers import Dense 
from tensorflow.keras import regularizers
tf.random.set_seed(10)
act_func = 'relu'

# Input layer:
model=Sequential()
# First hidden layer, connected to input vector X.
model.add(Dense(10,activation=act_func,
                kernel_initializer='glorot_uniform',
                kernel_regularizer=regularizers.l2(0.0),
                input_shape=(X_train.shape[1],)
               )
         )

model.add(Dense(2,activation=act_func,
                kernel_initializer='glorot_uniform'))

model.add(Dense(10,activation=act_func,
                kernel_initializer='glorot_uniform'))

model.add(Dense(X_train.shape[1],
                kernel_initializer='glorot_uniform'))

model.compile(loss='mse',optimizer='adam')

print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 22
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_3 (Dense)              (None, 31)                341
# =================================================================
# Total params: 713
# Trainable params: 713
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train model for 100 epochs, batch size of 10:
NUM_EPOCHS=100
BATCH_SIZE=10


history=model.fit(np.array(X_train),np.array(X_train),
                  batch_size=BATCH_SIZE,
                  epochs=NUM_EPOCHS,
                  validation_split=0.05,
                  verbose = 1)

plt.plot(history.history['loss'],
         'b',
         label='Training loss')
plt.plot(history.history['val_loss'],
         'r',
         label='Validation loss')
plt.legend(loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Loss, [mse]')
plt.ylim([0,.1])
plt.show()
# Out:
# Epoch 1/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0184 - val_loss: 0.0580
# Epoch 2/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0121 - val_loss: 0.0542
# Epoch 3/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0090 - val_loss: 0.0452
# Epoch 4/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0082 - val_loss: 0.0503
# Epoch 5/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0080 - val_loss: 0.0534
# Epoch 6/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0078 - val_loss: 0.0524
# Epoch 7/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0076 - val_loss: 0.0471
# Epoch 8/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0074 - val_loss: 0.0451
# Epoch 9/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0073 - val_loss: 0.0518
# Epoch 10/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0073 - val_loss: 0.0467
# Epoch 11/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0072 - val_loss: 0.0477
# Epoch 12/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0072 - val_loss: 0.0496
# Epoch 13/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0072 - val_loss: 0.0511
# Epoch 14/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0476
# Epoch 15/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0460
# Epoch 16/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0575
# Epoch 17/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0541
# Epoch 18/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0456
# Epoch 19/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0488
# Epoch 20/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0506
# Epoch 21/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0491
# Epoch 22/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0524
# Epoch 23/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0071 - val_loss: 0.0542
# Epoch 24/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0528
# Epoch 25/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0071 - val_loss: 0.0552
# Epoch 26/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0516
# Epoch 27/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0453
# Epoch 28/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0549
# Epoch 29/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0435
# Epoch 30/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0500
# Epoch 31/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0489
# Epoch 32/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0498
# Epoch 33/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0498
# Epoch 34/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0459
# Epoch 35/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0513
# Epoch 36/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0511
# Epoch 37/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0070 - val_loss: 0.0495
# Epoch 38/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0449
# Epoch 39/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0433
# Epoch 40/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0518
# Epoch 41/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0467
# Epoch 42/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0510
# Epoch 43/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0529
# Epoch 44/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0461
# Epoch 45/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0462
# Epoch 46/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0442
# Epoch 47/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0425
# Epoch 48/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0419
# Epoch 49/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0070 - val_loss: 0.0468
# Epoch 50/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0473
# Epoch 51/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0510
# Epoch 52/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0469
# Epoch 53/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0454
# Epoch 54/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0472
# Epoch 55/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0471
# Epoch 56/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0508
# Epoch 57/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0464
# Epoch 58/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0508
# Epoch 59/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0507
# Epoch 60/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0485
# Epoch 61/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0070 - val_loss: 0.0514
# Epoch 62/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0480
# Epoch 63/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0554
# Epoch 64/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0471
# Epoch 65/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0477
# Epoch 66/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0495
# Epoch 67/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0404
# Epoch 68/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0064 - val_loss: 0.0311
# Epoch 69/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0052 - val_loss: 0.0274
# Epoch 70/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0051 - val_loss: 0.0208
# Epoch 71/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0050 - val_loss: 0.0162
# Epoch 72/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0049 - val_loss: 0.0153
# Epoch 73/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0048 - val_loss: 0.0146
# Epoch 74/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0140
# Epoch 75/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0048 - val_loss: 0.0172
# Epoch 76/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0047 - val_loss: 0.0154
# Epoch 77/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0047 - val_loss: 0.0145
# Epoch 78/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0047 - val_loss: 0.0127
# Epoch 79/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0120
# Epoch 80/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0132
# Epoch 81/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0047 - val_loss: 0.0131
# Epoch 82/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0047 - val_loss: 0.0131
# Epoch 83/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0047 - val_loss: 0.0132
# Epoch 84/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0047 - val_loss: 0.0122
# Epoch 85/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 86/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0150
# Epoch 87/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0046 - val_loss: 0.0121
# Epoch 88/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 89/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0046 - val_loss: 0.0114
# Epoch 90/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0124
# Epoch 91/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0126
# Epoch 92/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0130
# Epoch 93/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0046 - val_loss: 0.0129
# Epoch 94/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0046 - val_loss: 0.0126
# Epoch 95/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 96/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0046 - val_loss: 0.0115
# Epoch 97/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 98/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0121
# Epoch 99/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0125
# Epoch 100/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0046 - val_loss: 0.0136

# %%
X_pred = model.predict(np.array(X_train))
X_pred = pd.DataFrame(X_pred,
                      columns=X_train.columns)
X_pred.index = X_train.index

scored = pd.DataFrame(index=X_train.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_train), axis = 1)
plt.figure()
sns.distplot(scored['Loss_mae'],
             bins = 10,
             kde= True,
            color = 'blue')
plt.xlim([0.0,.5])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 0.5)

# %%
X_pred = model.predict(np.array(X_test))
X_pred = pd.DataFrame(X_pred,
                      columns=X_test.columns)
X_pred.index = X_test.index


threshod = 0.3
scored = pd.DataFrame(index=X_test.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_test), axis = 1)
scored['Threshold'] = threshod
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()

X_pred_train = model.predict(np.array(X_train))
X_pred_train = pd.DataFrame(X_pred_train,
                      columns=X_train.columns)
X_pred_train.index = X_train.index

scored_train = pd.DataFrame(index=X_train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-X_train), axis = 1)
scored_train['Threshold'] = threshod
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])

scored.plot(logy=True,  figsize = (10,6), ylim = [1e-2,1e2], color = ['blue','red'])

# %%
merged_data1 = pd.read_csv('/content/2nd_test/train.csv',index_col= 'actc2',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
merged_data2 = pd.read_csv('/content/2nd_test/test2.csv',index_col= 'actc2',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
dataset_train = merged_data1 
dataset_test = merged_data2
dataset_train.plot(figsize = (12,6))

# %%
scaler = preprocessing.MinMaxScaler()

X_train = pd.DataFrame(scaler.fit_transform(dataset_train),
                              columns=dataset_train.columns,
                              index=dataset_train.index)
# Random shuffle training data
X_train.sample(frac=1)

X_test = pd.DataFrame(scaler.transform(dataset_test),
                             columns=dataset_test.columns,
                             index=dataset_test.index)
X_test.plot()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, svd_solver= 'full')
X_train_PCA = pca.fit_transform(X_train)
X_train_PCA = pd.DataFrame(X_train_PCA)
X_train_PCA.index = X_train.index

X_test_PCA = pca.transform(X_test)
X_test_PCA = pd.DataFrame(X_test_PCA)
X_test_PCA.index = X_test.index

X_train_PCA.plot()
X_test_PCA.plot()

# %%
def is_pos_def(A):
    if np.allclose(A, A.T): # check if A is Symmetric Matrices
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

def cov_matrix(data):
    covariance_matrix = np.cov(data, rowvar=False)
    if is_pos_def(covariance_matrix):
        inv_covariance_matrix = np.linalg.inv(covariance_matrix)
        if is_pos_def(inv_covariance_matrix):
            return covariance_matrix, inv_covariance_matrix
        else:
            print("Error: Inverse of Covariance Matrix is not positive definite!")
    else:
        print("Error: Covariance Matrix is not positive definite!")

def MahalanobisDist(inv_cov_matrix, mean_distr, data, verbose=False):
    inv_covariance_matrix = inv_cov_matrix
    vars_mean = mean_distr
    diff = data - vars_mean
    md = []
    for i in range(len(diff)):
        md.append(np.sqrt(diff[i].dot(inv_covariance_matrix).dot(diff[i])))
    return md

def MD_threshold(dist, extreme=False, verbose=False):
    k = 3. if extreme else 2.
    threshold = np.mean(dist) * k
    return threshold

data_train = np.array(X_train_PCA.values)
data_test = np.array(X_test_PCA.values)
cov_matrix, inv_cov_matrix  = cov_matrix(data_train)
mean_distr = data_train.mean(axis=0)
dist_test = MahalanobisDist(inv_cov_matrix, mean_distr, data_test, verbose=False)
dist_train = MahalanobisDist(inv_cov_matrix, mean_distr, data_train, verbose=False)
threshold = MD_threshold(dist_train, extreme = True)

# %%
plt.figure()
sns.distplot(np.square(dist_train),
             bins = 10,
             kde= False)
plt.xlim([0.0,15])
plt.xlabel('Mahalanobis dist *2')

plt.figure()
sns.distplot(dist_train,
             bins = 10,
             kde= True,
            color = 'green')
plt.xlim([0.0,5])
plt.xlabel('Mahalanobis dist')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Mahalanobis dist')

# %%
anomaly_train = pd.DataFrame()
anomaly_train['Mob dist']= dist_train
anomaly_train['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly_train['Anomaly'] = anomaly_train['Mob dist'] > anomaly_train['Thresh']
anomaly_train.index = X_train_PCA.index

anomaly = pd.DataFrame()
anomaly['Mob dist']= dist_test
anomaly['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly['Anomaly'] = anomaly['Mob dist'] > anomaly['Thresh']
anomaly.index = X_test_PCA.index
print(anomaly.head())
anomaly_alldata = pd.concat([anomaly_train, anomaly])
anomaly_alldata.to_csv('Anomaly_distance1.csv')
# Out:
#        Mob dist    Thresh  Anomaly
# actc2
# 8      1.524575  3.848719    False
# 8      1.523900  3.848719    False
# 8      1.524410  3.848719    False
# 8      1.524477  3.848719    False
# 8      1.524095  3.848719    False

# %%
anomaly_alldata.plot(logy=True, figsize = (10,6), ylim = [1e-1,1e3], color = ['green','red'])

# %%
import tensorflow as tf
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import Input 
from keras.models import Model 
from keras.layers import Dense 
from tensorflow.keras import regularizers
tf.random.set_seed(10)
act_func = 'relu'

# Input layer:
model=Sequential()
# First hidden layer, connected to input vector X.
model.add(Dense(10,activation=act_func,
                kernel_initializer='glorot_uniform',
                kernel_regularizer=regularizers.l2(0.0),
                input_shape=(X_train.shape[1],)
               )
         )

model.add(Dense(2,activation=act_func,
                kernel_initializer='glorot_uniform'))

model.add(Dense(10,activation=act_func,
                kernel_initializer='glorot_uniform'))

model.add(Dense(X_train.shape[1],
                kernel_initializer='glorot_uniform'))

model.compile(loss='mse',optimizer='adam')

print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 10)                320
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 22
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_7 (Dense)              (None, 31)                341
# =================================================================
# Total params: 713
# Trainable params: 713
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train model for 100 epochs, batch size of 10:
NUM_EPOCHS=100
BATCH_SIZE=10


history=model.fit(np.array(X_train),np.array(X_train),
                  batch_size=BATCH_SIZE,
                  epochs=NUM_EPOCHS,
                  validation_split=0.05,
                  verbose = 1)

plt.plot(history.history['loss'],
         'b',
         label='Training loss')
plt.plot(history.history['val_loss'],
         'r',
         label='Validation loss')
plt.legend(loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Loss, [mse]')
plt.ylim([0,.1])
plt.show()
# Out:
# Epoch 1/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0184 - val_loss: 0.0580
# Epoch 2/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0121 - val_loss: 0.0542
# Epoch 3/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0090 - val_loss: 0.0452
# Epoch 4/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0082 - val_loss: 0.0503
# Epoch 5/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0080 - val_loss: 0.0534
# Epoch 6/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0078 - val_loss: 0.0524
# Epoch 7/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0076 - val_loss: 0.0471
# Epoch 8/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0074 - val_loss: 0.0451
# Epoch 9/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0073 - val_loss: 0.0518
# Epoch 10/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0073 - val_loss: 0.0467
# Epoch 11/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0477
# Epoch 12/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0496
# Epoch 13/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0072 - val_loss: 0.0511
# Epoch 14/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0476
# Epoch 15/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0460
# Epoch 16/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0575
# Epoch 17/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0541
# Epoch 18/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0456
# Epoch 19/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0488
# Epoch 20/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0071 - val_loss: 0.0506
# Epoch 21/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0491
# Epoch 22/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0524
# Epoch 23/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0542
# Epoch 24/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0528
# Epoch 25/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0552
# Epoch 26/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0516
# Epoch 27/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0453
# Epoch 28/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0549
# Epoch 29/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0435
# Epoch 30/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0500
# Epoch 31/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0489
# Epoch 32/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0498
# Epoch 33/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0498
# Epoch 34/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0459
# Epoch 35/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0513
# Epoch 36/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0511
# Epoch 37/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0495
# Epoch 38/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0449
# Epoch 39/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0433
# Epoch 40/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0518
# Epoch 41/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0467
# Epoch 42/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0510
# Epoch 43/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0529
# Epoch 44/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0461
# Epoch 45/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0070 - val_loss: 0.0462
# Epoch 46/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0442
# Epoch 47/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0425
# Epoch 48/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0419
# Epoch 49/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0468
# Epoch 50/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0473
# Epoch 51/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0510
# Epoch 52/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0469
# Epoch 53/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0454
# Epoch 54/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0472
# Epoch 55/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0471
# Epoch 56/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0508
# Epoch 57/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0464
# Epoch 58/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0070 - val_loss: 0.0508
# Epoch 59/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0507
# Epoch 60/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0485
# Epoch 61/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0514
# Epoch 62/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0480
# Epoch 63/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0554
# Epoch 64/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0471
# Epoch 65/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0477
# Epoch 66/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0495
# Epoch 67/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0404
# Epoch 68/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0064 - val_loss: 0.0311
# Epoch 69/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0052 - val_loss: 0.0274
# Epoch 70/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0051 - val_loss: 0.0208
# Epoch 71/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0050 - val_loss: 0.0162
# Epoch 72/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0049 - val_loss: 0.0153
# Epoch 73/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0146
# Epoch 74/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0140
# Epoch 75/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0172
# Epoch 76/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0154
# Epoch 77/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0047 - val_loss: 0.0145
# Epoch 78/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0127
# Epoch 79/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0120
# Epoch 80/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0047 - val_loss: 0.0132
# Epoch 81/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0131
# Epoch 82/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0047 - val_loss: 0.0131
# Epoch 83/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0047 - val_loss: 0.0132
# Epoch 84/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0122
# Epoch 85/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 86/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0150
# Epoch 87/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0121
# Epoch 88/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 89/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0114
# Epoch 90/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0124
# Epoch 91/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0126
# Epoch 92/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0046 - val_loss: 0.0130
# Epoch 93/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0129
# Epoch 94/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0126
# Epoch 95/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 96/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0115
# Epoch 97/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 98/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0121
# Epoch 99/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0125
# Epoch 100/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0136

# %%
X_pred = model.predict(np.array(X_train))
X_pred = pd.DataFrame(X_pred,
                      columns=X_train.columns)
X_pred.index = X_train.index

scored = pd.DataFrame(index=X_train.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_train), axis = 1)
plt.figure()
sns.distplot(scored['Loss_mae'],
             bins = 10,
             kde= True,
            color = 'blue')
plt.xlim([0.0,.5])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 0.5)

# %%
X_pred = model.predict(np.array(X_test))
X_pred = pd.DataFrame(X_pred,
                      columns=X_test.columns)
X_pred.index = X_test.index


threshod = 0.3
scored = pd.DataFrame(index=X_test.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_test), axis = 1)
scored['Threshold'] = threshod
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()

X_pred_train = model.predict(np.array(X_train))
X_pred_train = pd.DataFrame(X_pred_train,
                      columns=X_train.columns)
X_pred_train.index = X_train.index

scored_train = pd.DataFrame(index=X_train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-X_train), axis = 1)
scored_train['Threshold'] = threshod
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])

scored.plot(logy=True,  figsize = (10,6), ylim = [1e-2,1e2], color = ['blue','red'])

# %%
merged_data1 = pd.read_csv('/content/2nd_test/train.csv',index_col= 'actc2',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
merged_data2 = pd.read_csv('/content/2nd_test/test3.csv',index_col= 'actc2',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
dataset_train = merged_data1 
dataset_test = merged_data2
dataset_train.plot(figsize = (12,6))

# %%
scaler = preprocessing.MinMaxScaler()

X_train = pd.DataFrame(scaler.fit_transform(dataset_train),
                              columns=dataset_train.columns,
                              index=dataset_train.index)
# Random shuffle training data
X_train.sample(frac=1)

X_test = pd.DataFrame(scaler.transform(dataset_test),
                             columns=dataset_test.columns,
                             index=dataset_test.index)
X_test.plot()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, svd_solver= 'full')
X_train_PCA = pca.fit_transform(X_train)
X_train_PCA = pd.DataFrame(X_train_PCA)
X_train_PCA.index = X_train.index

X_test_PCA = pca.transform(X_test)
X_test_PCA = pd.DataFrame(X_test_PCA)
X_test_PCA.index = X_test.index

X_train_PCA.plot()
X_test_PCA.plot()

# %%
def is_pos_def(A):
    if np.allclose(A, A.T): # check if A is Symmetric Matrices
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

def cov_matrix(data):
    covariance_matrix = np.cov(data, rowvar=False)
    if is_pos_def(covariance_matrix):
        inv_covariance_matrix = np.linalg.inv(covariance_matrix)
        if is_pos_def(inv_covariance_matrix):
            return covariance_matrix, inv_covariance_matrix
        else:
            print("Error: Inverse of Covariance Matrix is not positive definite!")
    else:
        print("Error: Covariance Matrix is not positive definite!")

def MahalanobisDist(inv_cov_matrix, mean_distr, data, verbose=False):
    inv_covariance_matrix = inv_cov_matrix
    vars_mean = mean_distr
    diff = data - vars_mean
    md = []
    for i in range(len(diff)):
        md.append(np.sqrt(diff[i].dot(inv_covariance_matrix).dot(diff[i])))
    return md

def MD_threshold(dist, extreme=False, verbose=False):
    k = 3. if extreme else 2.
    threshold = np.mean(dist) * k
    return threshold

data_train = np.array(X_train_PCA.values)
data_test = np.array(X_test_PCA.values)
cov_matrix, inv_cov_matrix  = cov_matrix(data_train)
mean_distr = data_train.mean(axis=0)
dist_test = MahalanobisDist(inv_cov_matrix, mean_distr, data_test, verbose=False)
dist_train = MahalanobisDist(inv_cov_matrix, mean_distr, data_train, verbose=False)
threshold = MD_threshold(dist_train, extreme = True)

# %%
plt.figure()
sns.distplot(np.square(dist_train),
             bins = 10,
             kde= False)
plt.xlim([0.0,15])
plt.xlabel('Mahalanobis dist *2')

plt.figure()
sns.distplot(dist_train,
             bins = 10,
             kde= True,
            color = 'green')
plt.xlim([0.0,5])
plt.xlabel('Mahalanobis dist')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Mahalanobis dist')

# %%
anomaly_train = pd.DataFrame()
anomaly_train['Mob dist']= dist_train
anomaly_train['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly_train['Anomaly'] = anomaly_train['Mob dist'] > anomaly_train['Thresh']
anomaly_train.index = X_train_PCA.index

anomaly = pd.DataFrame()
anomaly['Mob dist']= dist_test
anomaly['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly['Anomaly'] = anomaly['Mob dist'] > anomaly['Thresh']
anomaly.index = X_test_PCA.index
print(anomaly.head())
anomaly_alldata = pd.concat([anomaly_train, anomaly])
anomaly_alldata.to_csv('Anomaly_distance2.csv')
# Out:
#        Mob dist    Thresh  Anomaly
# actc2
# 9      1.296485  3.848719    False
# 9      1.294633  3.848719    False
# 9      1.298494  3.848719    False
# 9      1.303135  3.848719    False
# 9      1.307449  3.848719    False

# %%
anomaly_alldata.plot(logy=True, figsize = (10,6), ylim = [1e-1,1e3], color = ['green','red'])

# %%
import tensorflow as tf
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import Input 
from keras.models import Model 
from keras.layers import Dense 
from tensorflow.keras import regularizers
tf.random.set_seed(10)
act_func = 'relu'

# Input layer:
model=Sequential()
# First hidden layer, connected to input vector X.
model.add(Dense(10,activation=act_func,
                kernel_initializer='glorot_uniform',
                kernel_regularizer=regularizers.l2(0.0),
                input_shape=(X_train.shape[1],)
               )
         )

model.add(Dense(2,activation=act_func,
                kernel_initializer='glorot_uniform'))

model.add(Dense(10,activation=act_func,
                kernel_initializer='glorot_uniform'))

model.add(Dense(X_train.shape[1],
                kernel_initializer='glorot_uniform'))

model.compile(loss='mse',optimizer='adam')

print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                320
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 22
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_11 (Dense)             (None, 31)                341
# =================================================================
# Total params: 713
# Trainable params: 713
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train model for 100 epochs, batch size of 10:
NUM_EPOCHS=100
BATCH_SIZE=10


history=model.fit(np.array(X_train),np.array(X_train),
                  batch_size=BATCH_SIZE,
                  epochs=NUM_EPOCHS,
                  validation_split=0.05,
                  verbose = 1)

plt.plot(history.history['loss'],
         'b',
         label='Training loss')
plt.plot(history.history['val_loss'],
         'r',
         label='Validation loss')
plt.legend(loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Loss, [ mse]')
plt.ylim([0,.1])
plt.show()
# Out:
# Epoch 1/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0184 - val_loss: 0.0580
# Epoch 2/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0121 - val_loss: 0.0542
# Epoch 3/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0090 - val_loss: 0.0452
# Epoch 4/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0082 - val_loss: 0.0503
# Epoch 5/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0080 - val_loss: 0.0534
# Epoch 6/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0078 - val_loss: 0.0524
# Epoch 7/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0076 - val_loss: 0.0471
# Epoch 8/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0074 - val_loss: 0.0451
# Epoch 9/100
# 19000/19000 [==============================] - 31s 2ms/step - loss: 0.0073 - val_loss: 0.0518
# Epoch 10/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0073 - val_loss: 0.0467
# Epoch 11/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0072 - val_loss: 0.0477
# Epoch 12/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0072 - val_loss: 0.0496
# Epoch 13/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0072 - val_loss: 0.0511
# Epoch 14/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0072 - val_loss: 0.0476
# Epoch 15/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0072 - val_loss: 0.0460
# Epoch 16/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0072 - val_loss: 0.0575
# Epoch 17/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0541
# Epoch 18/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0456
# Epoch 19/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0488
# Epoch 20/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0071 - val_loss: 0.0506
# Epoch 21/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0071 - val_loss: 0.0491
# Epoch 22/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0524
# Epoch 23/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0542
# Epoch 24/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0528
# Epoch 25/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0552
# Epoch 26/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0516
# Epoch 27/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0453
# Epoch 28/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0549
# Epoch 29/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0071 - val_loss: 0.0435
# Epoch 30/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0500
# Epoch 31/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0071 - val_loss: 0.0489
# Epoch 32/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0498
# Epoch 33/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0070 - val_loss: 0.0498
# Epoch 34/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0459
# Epoch 35/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0513
# Epoch 36/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0511
# Epoch 37/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0495
# Epoch 38/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0449
# Epoch 39/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0071 - val_loss: 0.0433
# Epoch 40/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0518
# Epoch 41/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0467
# Epoch 42/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0510
# Epoch 43/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0070 - val_loss: 0.0529
# Epoch 44/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0461
# Epoch 45/100
# 19000/19000 [==============================] - 30s 2ms/step - loss: 0.0070 - val_loss: 0.0462
# Epoch 46/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0442
# Epoch 47/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0425
# Epoch 48/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0419
# Epoch 49/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0468
# Epoch 50/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0473
# Epoch 51/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0510
# Epoch 52/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0469
# Epoch 53/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0454
# Epoch 54/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0472
# Epoch 55/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0471
# Epoch 56/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 0.0508
# Epoch 57/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0070 - val_loss: 0.0464
# Epoch 58/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0508
# Epoch 59/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0507
# Epoch 60/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0485
# Epoch 61/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0514
# Epoch 62/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0480
# Epoch 63/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0554
# Epoch 64/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0471
# Epoch 65/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0070 - val_loss: 0.0477
# Epoch 66/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0495
# Epoch 67/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0070 - val_loss: 0.0404
# Epoch 68/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0064 - val_loss: 0.0311
# Epoch 69/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0052 - val_loss: 0.0274
# Epoch 70/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0051 - val_loss: 0.0208
# Epoch 71/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0050 - val_loss: 0.0162
# Epoch 72/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0049 - val_loss: 0.0153
# Epoch 73/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0146
# Epoch 74/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0140
# Epoch 75/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0172
# Epoch 76/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0047 - val_loss: 0.0154
# Epoch 77/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0145
# Epoch 78/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0127
# Epoch 79/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0120
# Epoch 80/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0047 - val_loss: 0.0132
# Epoch 81/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0131
# Epoch 82/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0131
# Epoch 83/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0132
# Epoch 84/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0047 - val_loss: 0.0122
# Epoch 85/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 86/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0150
# Epoch 87/100
# 19000/19000 [==============================] - 29s 2ms/step - loss: 0.0046 - val_loss: 0.0121
# Epoch 88/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 89/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0114
# Epoch 90/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0124
# Epoch 91/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0126
# Epoch 92/100
# 19000/19000 [==============================] - 30s 2ms/step - loss: 0.0046 - val_loss: 0.0130
# Epoch 93/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0129
# Epoch 94/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0126
# Epoch 95/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 96/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0115
# Epoch 97/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 98/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0121
# Epoch 99/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0046 - val_loss: 0.0125
# Epoch 100/100
# 19000/19000 [==============================] - 28s 1ms/step - loss: 0.0046 - val_loss: 0.0136

# %%
X_pred = model.predict(np.array(X_train))
X_pred = pd.DataFrame(X_pred,
                      columns=X_train.columns)
X_pred.index = X_train.index

scored = pd.DataFrame(index=X_train.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_train), axis = 1)
plt.figure()
sns.distplot(scored['Loss_mae'],
             bins = 10,
             kde= True,
            color = 'blue')
plt.xlim([0.0,.5])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 0.5)

# %%
X_pred = model.predict(np.array(X_test))
X_pred = pd.DataFrame(X_pred,
                      columns=X_test.columns)
X_pred.index = X_test.index


threshod = 0.3
scored = pd.DataFrame(index=X_test.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_test), axis = 1)
scored['Threshold'] = threshod
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()

X_pred_train = model.predict(np.array(X_train))
X_pred_train = pd.DataFrame(X_pred_train,
                      columns=X_train.columns)
X_pred_train.index = X_train.index

scored_train = pd.DataFrame(index=X_train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-X_train), axis = 1)
scored_train['Threshold'] = threshod
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])

scored.plot(logy=True,  figsize = (10,6), ylim = [1e-2,1e2], color = ['blue','red'])

# %%
merged_data1 = pd.read_csv('/content/2nd_test/train.csv' ,usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
merged_data2 = pd.read_csv('/content/2nd_test/test3.csv',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
dataset_train = merged_data1 
dataset_test = merged_data2
dataset_train.plot(figsize = (12,6))

# %%
scaler = preprocessing.MinMaxScaler()

X_train = pd.DataFrame(scaler.fit_transform(dataset_train),
                              columns=dataset_train.columns,
                              index=dataset_train.index)
# Random shuffle training data
X_train.sample(frac=1)

X_test = pd.DataFrame(scaler.transform(dataset_test),
                             columns=dataset_test.columns,
                             index=dataset_test.index)
X_test.plot()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, svd_solver= 'full')
X_train_PCA = pca.fit_transform(X_train)
X_train_PCA = pd.DataFrame(X_train_PCA)
X_train_PCA.index = X_train.index

X_test_PCA = pca.transform(X_test)
X_test_PCA = pd.DataFrame(X_test_PCA)
X_test_PCA.index = X_test.index

X_train_PCA.plot()
X_test_PCA.plot()

# %%
def is_pos_def(A):
    if np.allclose(A, A.T): # check if A is Symmetric Matrices
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

def cov_matrix(data):
    covariance_matrix = np.cov(data, rowvar=False)
    if is_pos_def(covariance_matrix):
        inv_covariance_matrix = np.linalg.inv(covariance_matrix)
        if is_pos_def(inv_covariance_matrix):
            return covariance_matrix, inv_covariance_matrix
        else:
            print("Error: Inverse of Covariance Matrix is not positive definite!")
    else:
        print("Error: Covariance Matrix is not positive definite!")

def MahalanobisDist(inv_cov_matrix, mean_distr, data, verbose=False):
    inv_covariance_matrix = inv_cov_matrix
    vars_mean = mean_distr
    diff = data - vars_mean
    md = []
    for i in range(len(diff)):
        md.append(np.sqrt(diff[i].dot(inv_covariance_matrix).dot(diff[i])))
    return md

def MD_threshold(dist, extreme=False, verbose=False):
    k = 3. if extreme else 2.
    threshold = np.mean(dist) * k
    return threshold

data_train = np.array(X_train_PCA.values)
data_test = np.array(X_test_PCA.values)
cov_matrix, inv_cov_matrix  = cov_matrix(data_train)
mean_distr = data_train.mean(axis=0)
dist_test = MahalanobisDist(inv_cov_matrix, mean_distr, data_test, verbose=False)
dist_train = MahalanobisDist(inv_cov_matrix, mean_distr, data_train, verbose=False)
threshold = MD_threshold(dist_train, extreme = True)

# %%
plt.figure()
sns.distplot(np.square(dist_train),
             bins = 10,
             kde= False)
plt.xlim([0.0,15])
plt.xlabel('Mahalanobis dist *2')

plt.figure()
sns.distplot(dist_train,
             bins = 10,
             kde= True,
            color = 'green')
plt.xlim([0.0,5])
plt.xlabel('Mahalanobis dist')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Mahalanobis dist')

# %%
anomaly_train = pd.DataFrame()
anomaly_train['Mob dist']= dist_train
anomaly_train['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly_train['Anomaly'] = anomaly_train['Mob dist'] > anomaly_train['Thresh']
anomaly_train.index = X_train_PCA.index

anomaly = pd.DataFrame()
anomaly['Mob dist']= dist_test
anomaly['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly['Anomaly'] = anomaly['Mob dist'] > anomaly['Thresh']
anomaly.index = X_test_PCA.index
print(anomaly.head())
anomaly_alldata = pd.concat([anomaly_train, anomaly])
anomaly_alldata.to_csv('Anomaly_distance3.csv')
# Out:
#    Mob dist    Thresh  Anomaly
# 0  1.329842  3.873082    False
# 1  1.327935  3.873082    False
# 2  1.331586  3.873082    False
# 3  1.335930  3.873082    False
# 4  1.340030  3.873082    False

# %%
anomaly
# Out:
#           Mob dist    Thresh  Anomaly
# 0         1.329842  3.873082    False
# 1         1.327935  3.873082    False
# 2         1.331586  3.873082    False
# 3         1.335930  3.873082    False
# 4         1.340030  3.873082    False
# ...            ...       ...      ...
# 49995  1364.611144  3.873082     True
# 49996  1364.611689  3.873082     True
# 49997  1364.611750  3.873082     True
# 49998  1364.612154  3.873082     True
# 49999  1364.613741  3.873082     True
#
# [50000 rows x 3 columns]

# %%
anomaly.plot(logy=True, figsize = (10,6), ylim = [1e-1,1e3], color = ['green','red'])

# %%
anomaly_alldata.plot(logy=True, figsize = (10,6), ylim = [1e-1,1e3], color = ['green','red'])

# %%
import tensorflow as tf
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import Input 
from keras.models import Model 
from keras.layers import Dense 
from tensorflow.keras import regularizers
tf.random.set_seed(10)
act_func = 'relu'

# Input layer:
model=Sequential()
# First hidden layer, connected to input vector X.
model.add(Dense(10,activation=act_func,
                kernel_initializer='glorot_uniform',
                kernel_regularizer=regularizers.l2(0.0),
                input_shape=(X_train.shape[1],)
               )
         )

model.add(Dense(2,activation=act_func,
                kernel_initializer='glorot_uniform'))

model.add(Dense(10,activation=act_func,
                kernel_initializer='glorot_uniform'))

model.add(Dense(X_train.shape[1],
                kernel_initializer='glorot_uniform'))

model.compile(loss='mse',optimizer='adam')

print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                330
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 22
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                352
# =================================================================
# Total params: 734
# Trainable params: 734
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train model for 100 epochs, batch size of 10:
NUM_EPOCHS=100
BATCH_SIZE=10


history=model.fit(np.array(X_train),np.array(X_train),
                  batch_size=BATCH_SIZE,
                  epochs=NUM_EPOCHS,
                  validation_split=0.05,
                  verbose = 1)

plt.plot(history.history['loss'],
         'b',
         label='Training loss')
plt.plot(history.history['val_loss'],
         'r',
         label='Validation loss')
plt.legend(loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Loss, [ mse]')
plt.ylim([0,.1])
plt.show()
# Out:
# Epoch 1/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0064 - val_loss: 0.0229
# Epoch 2/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0061 - val_loss: 0.0160
# Epoch 3/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0057 - val_loss: 0.0164
# Epoch 4/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0055 - val_loss: 0.0161
# Epoch 5/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0053 - val_loss: 0.0179
# Epoch 6/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0053 - val_loss: 0.0163
# Epoch 7/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0052 - val_loss: 0.0151
# Epoch 8/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0052 - val_loss: 0.0134
# Epoch 9/100
# 19000/19000 [==============================] - 25s 1ms/step - loss: 0.0052 - val_loss: 0.0133
# Epoch 10/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0051 - val_loss: 0.0143
# Epoch 11/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0051 - val_loss: 0.0142
# Epoch 12/100
# 19000/19000 [==============================] - 25s 1ms/step - loss: 0.0050 - val_loss: 0.0133
# Epoch 13/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0050 - val_loss: 0.0138
# Epoch 14/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0050 - val_loss: 0.0133
# Epoch 15/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0050 - val_loss: 0.0122
# Epoch 16/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0145
# Epoch 17/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0149
# Epoch 18/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0134
# Epoch 19/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0146
# Epoch 20/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0139
# Epoch 21/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0136
# Epoch 22/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0148
# Epoch 23/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0049 - val_loss: 0.0142
# Epoch 24/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0138
# Epoch 25/100
# 19000/19000 [==============================] - 25s 1ms/step - loss: 0.0049 - val_loss: 0.0141
# Epoch 26/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0049 - val_loss: 0.0133
# Epoch 27/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0145
# Epoch 28/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0146
# Epoch 29/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0134
# Epoch 30/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0150
# Epoch 31/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0134
# Epoch 32/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0142
# Epoch 33/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0139
# Epoch 34/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0136
# Epoch 35/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0140
# Epoch 36/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0139
# Epoch 37/100
# 19000/19000 [==============================] - 25s 1ms/step - loss: 0.0048 - val_loss: 0.0138
# Epoch 38/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0139
# Epoch 39/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0144
# Epoch 40/100
# 19000/19000 [==============================] - 23s 1ms/step - loss: 0.0048 - val_loss: 0.0134
# Epoch 41/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0132
# Epoch 42/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0143
# Epoch 43/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0138
# Epoch 44/100
# 19000/19000 [==============================] - 22s 1ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 45/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0148
# Epoch 46/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0136
# Epoch 47/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0131
# Epoch 48/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0135
# Epoch 49/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0131
# Epoch 50/100
# 19000/19000 [==============================] - 25s 1ms/step - loss: 0.0048 - val_loss: 0.0141
# Epoch 51/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 52/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0138
# Epoch 53/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0146
# Epoch 54/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0141
# Epoch 55/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0134
# Epoch 56/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0141
# Epoch 57/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0143
# Epoch 58/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0142
# Epoch 59/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0144
# Epoch 60/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0139
# Epoch 61/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0130
# Epoch 62/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0136
# Epoch 63/100
# 19000/19000 [==============================] - 26s 1ms/step - loss: 0.0048 - val_loss: 0.0154
# Epoch 64/100
# 19000/19000 [==============================] - 25s 1ms/step - loss: 0.0048 - val_loss: 0.0145
# Epoch 65/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0138
# Epoch 66/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0143
# Epoch 67/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 68/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0136
# Epoch 69/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0130
# Epoch 70/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0126
# Epoch 71/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0135
# Epoch 72/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0140
# Epoch 73/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 74/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0135
# Epoch 75/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 76/100
# 19000/19000 [==============================] - 25s 1ms/step - loss: 0.0048 - val_loss: 0.0143
# Epoch 77/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0136
# Epoch 78/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0127
# Epoch 79/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0128
# Epoch 80/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0136
# Epoch 81/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0141
# Epoch 82/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0123
# Epoch 83/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0125
# Epoch 84/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0148
# Epoch 85/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0139
# Epoch 86/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0124
# Epoch 87/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 88/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0132
# Epoch 89/100
# 19000/19000 [==============================] - 25s 1ms/step - loss: 0.0048 - val_loss: 0.0126
# Epoch 90/100
# 19000/19000 [==============================] - 27s 1ms/step - loss: 0.0048 - val_loss: 0.0131
# Epoch 91/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0139
# Epoch 92/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0131
# Epoch 93/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0144
# Epoch 94/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0136
# Epoch 95/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0142
# Epoch 96/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0130
# Epoch 97/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0132
# Epoch 98/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0127
# Epoch 99/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0141
# Epoch 100/100
# 19000/19000 [==============================] - 24s 1ms/step - loss: 0.0048 - val_loss: 0.0129

# %%
X_pred = model.predict(np.array(X_train))
X_pred = pd.DataFrame(X_pred,
                      columns=X_train.columns)
X_pred.index = X_train.index

scored = pd.DataFrame(index=X_train.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_train), axis = 1)
plt.figure()
sns.distplot(scored['Loss_mae'],
             bins = 10,
             kde= True,
            color = 'blue')
plt.xlim([0.0,.5])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 0.5)

# %%
X_pred = model.predict(np.array(X_test))
X_pred = pd.DataFrame(X_pred,
                      columns=X_test.columns)
X_pred.index = X_test.index


threshod = 0.2
scored = pd.DataFrame(index=X_test.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_test), axis = 1)
scored['Threshold'] = threshod
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()

X_pred_train = model.predict(np.array(X_train))
X_pred_train = pd.DataFrame(X_pred_train,
                      columns=X_train.columns)
X_pred_train.index = X_train.index

scored_train = pd.DataFrame(index=X_train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-X_train), axis = 1)
scored_train['Threshold'] = threshod
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])

scored.plot(logy=True,  figsize = (10,6), ylim = [1e-2,1e2], color = ['blue','red'])

# %%
X_pred = model.predict(np.array(X_test))
X_pred = pd.DataFrame(X_pred,
                      columns=X_test.columns)
X_pred.index = X_test.index


threshod = 2
scored = pd.DataFrame(index=X_test.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_test), axis = 1)
scored['Threshold'] = threshod
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
scored.plot(logy=True,  figsize = (10,6), ylim = [1e-2,1e2], color = ['blue','red'])

# %%
merged_data1 = pd.read_csv('/content/2nd_test/train.csv' ,usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
merged_data2 = pd.read_csv('/content/2nd_test/test2.csv',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
dataset_train = merged_data1 
dataset_test = merged_data2
dataset_train.plot(figsize = (12,6))

# %%
scaler = preprocessing.MinMaxScaler()

X_train = pd.DataFrame(scaler.fit_transform(dataset_train),
                              columns=dataset_train.columns,
                              index=dataset_train.index)
# Random shuffle training data
X_train.sample(frac=1)

X_test = pd.DataFrame(scaler.transform(dataset_test),
                             columns=dataset_test.columns,
                             index=dataset_test.index)
X_test.plot()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, svd_solver= 'full')
X_train_PCA = pca.fit_transform(X_train)
X_train_PCA = pd.DataFrame(X_train_PCA)
X_train_PCA.index = X_train.index

X_test_PCA = pca.transform(X_test)
X_test_PCA = pd.DataFrame(X_test_PCA)
X_test_PCA.index = X_test.index

X_train_PCA.plot()
X_test_PCA.plot()

# %%
def is_pos_def(A):
    if np.allclose(A, A.T): # check if A is Symmetric Matrices
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

def cov_matrix(data):
    covariance_matrix = np.cov(data, rowvar=False)
    if is_pos_def(covariance_matrix):
        inv_covariance_matrix = np.linalg.inv(covariance_matrix)
        if is_pos_def(inv_covariance_matrix):
            return covariance_matrix, inv_covariance_matrix
        else:
            print("Error: Inverse of Covariance Matrix is not positive definite!")
    else:
        print("Error: Covariance Matrix is not positive definite!")

def MahalanobisDist(inv_cov_matrix, mean_distr, data, verbose=False):
    inv_covariance_matrix = inv_cov_matrix
    vars_mean = mean_distr
    diff = data - vars_mean
    md = []
    for i in range(len(diff)):
        md.append(np.sqrt(diff[i].dot(inv_covariance_matrix).dot(diff[i])))
    return md

def MD_threshold(dist, extreme=False, verbose=False):
    k = 3. if extreme else 2.
    threshold = np.mean(dist) * k
    return threshold

data_train = np.array(X_train_PCA.values)
data_test = np.array(X_test_PCA.values)
cov_matrix, inv_cov_matrix  = cov_matrix(data_train)
mean_distr = data_train.mean(axis=0)
dist_test = MahalanobisDist(inv_cov_matrix, mean_distr, data_test, verbose=False)
dist_train = MahalanobisDist(inv_cov_matrix, mean_distr, data_train, verbose=False)
threshold = MD_threshold(dist_train, extreme = True)

# %%
plt.figure()
sns.distplot(np.square(dist_train),
             bins = 10,
             kde= False)
plt.xlim([0.0,15])
plt.xlabel('Mahalanobis dist *2')

plt.figure()
sns.distplot(dist_train,
             bins = 10,
             kde= True,
            color = 'green')
plt.xlim([0.0,5])
plt.xlabel('Mahalanobis dist')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Mahalanobis dist')

# %%
anomaly = pd.DataFrame()
anomaly['Mob dist']= dist_test
anomaly['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly['Anomaly'] = anomaly['Mob dist'] > anomaly['Thresh']
anomaly.index = X_test_PCA.index
print(anomaly.head())
anomaly_alldata.to_csv('Anomaly_distance22.csv')
# Out:
#    Mob dist    Thresh  Anomaly
# 0  1.595744  3.873082    False
# 1  1.595049  3.873082    False
# 2  1.595565  3.873082    False
# 3  1.595643  3.873082    False
# 4  1.595251  3.873082    False

# %%
anomaly.plot(logy=True, figsize = (10,6), ylim = [1e-1,1e3], color = ['green','red'])

# %%
merged_data1 = pd.read_csv('/content/2nd_test/train.csv' ,usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
merged_data2 = pd.read_csv('/content/2nd_test/test1.csv',usecols=['actc2','dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])
dataset_train = merged_data1 
dataset_test = merged_data2
dataset_train.plot(figsize = (12,6))

# %%
scaler = preprocessing.MinMaxScaler()

X_train = pd.DataFrame(scaler.fit_transform(dataset_train),
                              columns=dataset_train.columns,
                              index=dataset_train.index)
# Random shuffle training data
X_train.sample(frac=1)

X_test = pd.DataFrame(scaler.transform(dataset_test),
                             columns=dataset_test.columns,
                             index=dataset_test.index)
X_test.plot()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, svd_solver= 'full')
X_train_PCA = pca.fit_transform(X_train)
X_train_PCA = pd.DataFrame(X_train_PCA)
X_train_PCA.index = X_train.index

X_test_PCA = pca.transform(X_test)
X_test_PCA = pd.DataFrame(X_test_PCA)
X_test_PCA.index = X_test.index

X_train_PCA.plot()
X_test_PCA.plot()

# %%
def is_pos_def(A):
    if np.allclose(A, A.T): # check if A is Symmetric Matrices
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

def cov_matrix(data):
    covariance_matrix = np.cov(data, rowvar=False)
    if is_pos_def(covariance_matrix):
        inv_covariance_matrix = np.linalg.inv(covariance_matrix)
        if is_pos_def(inv_covariance_matrix):
            return covariance_matrix, inv_covariance_matrix
        else:
            print("Error: Inverse of Covariance Matrix is not positive definite!")
    else:
        print("Error: Covariance Matrix is not positive definite!")

def MahalanobisDist(inv_cov_matrix, mean_distr, data, verbose=False):
    inv_covariance_matrix = inv_cov_matrix
    vars_mean = mean_distr
    diff = data - vars_mean
    md = []
    for i in range(len(diff)):
        md.append(np.sqrt(diff[i].dot(inv_covariance_matrix).dot(diff[i])))
    return md

def MD_threshold(dist, extreme=False, verbose=False):
    k = 3. if extreme else 2.
    threshold = np.mean(dist) * k
    return threshold

data_train = np.array(X_train_PCA.values)
data_test = np.array(X_test_PCA.values)
cov_matrix, inv_cov_matrix  = cov_matrix(data_train)
mean_distr = data_train.mean(axis=0)
dist_test = MahalanobisDist(inv_cov_matrix, mean_distr, data_test, verbose=False)
dist_train = MahalanobisDist(inv_cov_matrix, mean_distr, data_train, verbose=False)
threshold = MD_threshold(dist_train, extreme = True)

# %%
plt.figure()
sns.distplot(np.square(dist_train),
             bins = 10,
             kde= False)
plt.xlim([0.0,15])
plt.xlabel('Mahalanobis dist *2')

plt.figure()
sns.distplot(dist_train,
             bins = 10,
             kde= True,
            color = 'green')
plt.xlim([0.0,5])
plt.xlabel('Mahalanobis dist')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Mahalanobis dist')

# %%
anomaly = pd.DataFrame()
anomaly['Mob dist']= dist_test
anomaly['Thresh'] = threshold
# If Mob dist above threshold: Flag as anomaly
anomaly['Anomaly'] = anomaly['Mob dist'] > anomaly['Thresh']
anomaly.index = X_test_PCA.index
print(anomaly.head())
anomaly_alldata.to_csv('Anomaly_distance11.csv')
# Out:
#    Mob dist    Thresh  Anomaly
# 0  3.415678  3.873082    False
# 1  3.418905  3.873082    False
# 2  3.420487  3.873082    False
# 3  3.433453  3.873082    False
# 4  3.427863  3.873082    False

# %%
anomaly.plot(logy=True, figsize = (10,6), ylim = [0,1e1], color = ['green','red'])
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py:486: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(self.ylim)

# %%
X_pred = model.predict(np.array(X_test))
X_pred = pd.DataFrame(X_pred,
                      columns=X_test.columns)
X_pred.index = X_test.index


threshod = 0.2
scored = pd.DataFrame(index=X_test.index)
scored['Loss_mae'] = np.mean(np.abs(X_pred-X_test), axis = 1)
scored['Threshold'] = threshod
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()

X_pred_train = model.predict(np.array(X_train))
X_pred_train = pd.DataFrame(X_pred_train,
                      columns=X_train.columns)
X_pred_train.index = X_train.index

scored_train = pd.DataFrame(index=X_train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-X_train), axis = 1)
scored_train['Threshold'] = threshod
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])

scored.plot(logy=True,  figsize = (10,6), ylim = [1e-2,1e2], color = ['blue','red'])

# %%
import pandas as pd
df = pd.read_csv("/content/test1.csv")
df.fillna(value = df.mean(), inplace = True)
df.boxplot(column = ['dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])

# %%
t = df.iloc[:,1:]

# %%
t[abs(t - t.mean()) > 3*t.std()]
# Out:
#        dbtm  dbtv  dmea  dver  bpos  ropa  ...  lstk  drtm  gasa  spr1  spr2  spr3
# 0       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 49995   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 49996   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 49997   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 49998   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 49999   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
# [50000 rows x 36 columns]

# %%
t[abs(t - t.mean()) > 10*t.std()].to_csv('detectfinal1.csv')

# %%
t[abs(t-t.mean())>1.5*t.std()].dropna(how = 'all').to_csv('detect_test01.csv')

# %%
t
# Out:
#           dbtm  dbtv     dmea     dver  ...   gasa   spr1     spr2    spr3
# 0      3187.08     0  3187.14  3187.14  ...  26763  41.25  6002.96  377.01
# 1      3187.08     0  3187.14  3187.14  ...  26689  41.25  5979.17  377.01
# 2      3187.16     0  3187.17  3187.17  ...  26645  41.25  6002.94  377.01
# 3      3187.16     0  3187.18  3187.18  ...  26557  41.25  5979.28  377.05
# 4      3187.14     0  3187.18  3187.18  ...  26483  41.25  6010.99  377.05
# ...        ...   ...      ...      ...  ...    ...    ...      ...     ...
# 49995  3151.89     0  3223.00  3223.00  ...    199  46.62  5688.72  414.09
# 49996  3151.82     0  3223.00  3223.00  ...    198  46.62  5610.50  414.09
# 49997  3151.72     0  3223.00  3223.00  ...    199  46.62  5717.48  414.09
# 49998  3151.68     0  3223.00  3223.00  ...    197  46.62  5659.71  414.09
# 49999  3151.59     0  3223.00  3223.00  ...    190  46.62  5645.38  414.09
#
# [50000 rows x 36 columns]

# %%
def a1(dataframe, threshold=.95):
    d = dataframe['dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3']
    dataframe['isAnomaly'] = d > d.quantile(threshold)  
    return dataframe
print a1(df)
# Out:
#   File "<ipython-input-17-7d56d3349648>", line 5
#     print a1(df)
#            ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("/content/test2.csv")
df.fillna(value = df.mean(), inplace = True)
df.boxplot(column = ['dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])

# %%
t = df.iloc[:,1:]

# %%
t[abs(t - t.mean()) > 3*t.std()].to_csv('detecttest2.csv')

# %%
t[abs(t-t.mean())>10*t.std()].dropna(how = 'all').to_csv('detecttest02.csv')

# %%
df = pd.read_csv("/content/test3.csv")
df.fillna(value = df.mean(), inplace = True)
df.boxplot(column = ['dbtm','dbtv','dmea','dver','bpos','ropa','hkla', 	'woba',	'tqa', 	'rpma',	'sppa',	'chkp',	'spm1',	'spm2',	'spm3',	'tva',	'tvca',	'mfop',	'mfoa',	'mfia',	'mdoa',	'mdia',	'mtoa',	'mtia',	'mcoa',	 'stkc',	'drtm',	'gasa',	'spr1',	'spr2',	'spr3'])

# %%
t = df.iloc[:,1:]

# %%
t[abs(t-t.mean())>10*t.std()].dropna(how = 'all').to_csv('detecttest3.csv')
